# %%
## conda env Weather_Prediction

import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler 
import numpy as np
import seaborn as sns
from sklearn.metrics import mean_squared_error
import numpy as np
from sklearn.model_selection import GridSearchCV
from scipy.stats import pearsonr

from tensorflow import keras ## pip install tensorflow

# %%
## load the data

full_df = pd.read_pickle("2010_data.pkl")
full_df=full_df.drop(columns=['location_name', 'fips', 'year', 'NAME', 'geometry'],axis=1)
pd.set_option('display.max_columns', None)
full_df=full_df.dropna() ## get rid of NaN as MLP cannot handle it
full_df
# Out:
#       MeanLifeExpectency         d2m         t2m  bcaod550     chnk  duaod550  \
# 0              75.728489  283.454410  291.089093  0.006284  0.01800  0.010721
# 1              77.826608  286.767193  292.241782  0.006410  0.01527  0.013597
# 2              75.841973  284.124711  291.030084  0.006434  0.01800  0.010576
# 3              73.705432  283.448675  290.734945  0.006233  0.01800  0.010422
# 4              75.753407  282.868247  289.766565  0.006107  0.01800  0.008332
# ...                  ...         ...         ...       ...      ...       ...
# 3122           77.582422  268.842111  278.301219  0.004760  0.01800  0.004101
# 3123           83.771012  267.887551  274.410086  0.004909  0.01800  0.001664
# 3124           77.836526  270.017604  276.883251  0.004999  0.01800  0.002474
# 3125           78.674180  270.002497  279.090102  0.005382  0.01800  0.003850
# 3126           79.037741  271.900394  281.515954  0.005393  0.01800  0.007614
#
#         lai_hv    lai_lv            msl  omaod550         pm2p5          pm10  \
# 0     3.928873  2.633910  101693.509736  0.075966  1.445389e-08  1.981001e-08
# 1     3.930011  2.508253  101685.471788  0.072641  1.346257e-08  1.847324e-08
# 2     4.154440  2.339233  101690.626048  0.073790  1.528844e-08  2.094088e-08
# 3     3.859579  2.695780  101696.274163  0.077023  1.467121e-08  2.014099e-08
# 4     3.234586  2.781183  101710.006570  0.077158  1.519334e-08  2.097774e-08
# ...        ...       ...            ...       ...           ...           ...
# 3122  2.370862  0.499930  101630.449624  0.043633  7.253336e-09  1.103061e-08
# 3123  2.481296  2.428177  101634.772736  0.046080  6.861324e-09  9.790676e-09
# 3124  3.915328  0.601902  101654.328213  0.045505  7.911826e-09  1.138099e-08
# 3125  4.698226  0.552172  101447.562406  0.051272  7.706784e-09  1.107047e-08
# 3126  3.236533  0.630525  101428.707930  0.054691  1.063685e-08  1.666677e-08
#
#       ssaod550       asn         rsn        sd  suaod550             sp  \
# 0     0.007574  0.878745  271.096109  0.005542  0.071412  100187.304165
# 1     0.010417  0.879538  193.698250  0.004818  0.069880  101309.280631
# 2     0.007874  0.879026  245.431868  0.006236  0.067283  100229.513473
# 3     0.007201  0.878604  274.363643  0.005314  0.073008  100215.778699
# 4     0.006178  0.877193  276.665988  0.006156  0.074710   99027.783845
# ...        ...       ...         ...       ...       ...            ...
# 3122  0.005092  0.798388  288.873684  0.016426  0.023886   78530.596578
# 3123  0.006100  0.807739  305.402204  0.095034  0.021758   75497.845779
# 3124  0.005982  0.808222  293.046261  0.036183  0.024190   76929.110580
# 3125  0.004976  0.789770  287.155099  0.012652  0.022807   82346.540600
# 3126  0.004908  0.846356  281.809463  0.131075  0.025071   85890.203443
#
#              tsn    aod550      tcco   tc_c2h6        tchcho         tc_oh  \
# 0     272.665101  0.171956  0.000890  0.000003  4.351195e-06  4.876012e-09
# 1     275.408300  0.172946  0.000875  0.000003  3.513297e-06  4.926652e-09
# 2     272.708199  0.165957  0.000885  0.000003  4.161191e-06  4.878442e-09
# 3     272.652578  0.173887  0.000894  0.000003  4.369584e-06  4.879895e-09
# 4     272.614234  0.172485  0.000889  0.000003  4.043741e-06  4.893173e-09
# ...          ...       ...       ...       ...           ...           ...
# 3122  268.911264  0.081471  0.000644  0.000003  1.057299e-06  4.941603e-09
# 3123  268.751272  0.080511  0.000615  0.000003  8.352510e-07  4.851321e-09
# 3124  269.295318  0.083150  0.000625  0.000003  1.014339e-06  4.927959e-09
# 3125  269.500902  0.088287  0.000694  0.000003  1.081619e-06  4.902024e-09
# 3126  270.601870  0.097677  0.000736  0.000003  1.280696e-06  4.912921e-09
#
#            tc_c5h8    tc_ch4   tc_hno3     tcno2         tc_no     gtco3  \
# 0     3.973694e-06  0.009891  0.000005  0.000003  4.658415e-07  0.006583
# 1     2.062545e-06  0.010006  0.000005  0.000003  4.380713e-07  0.006433
# 2     3.484876e-06  0.009897  0.000005  0.000003  4.412445e-07  0.006521
# 3     3.844808e-06  0.009893  0.000005  0.000004  5.053737e-07  0.006622
# 4     2.631260e-06  0.009770  0.000005  0.000004  5.254242e-07  0.006689
# ...            ...       ...       ...       ...           ...       ...
# 3122  8.047194e-08  0.007655  0.000003  0.000002  4.937694e-07  0.006915
# 3123  7.964809e-08  0.007339  0.000003  0.000001  2.701267e-07  0.007030
# 3124  1.155312e-07  0.007492  0.000003  0.000002  3.589858e-07  0.006894
# 3125  6.101835e-08  0.008042  0.000003  0.000002  3.504658e-07  0.007063
# 3126  9.873015e-08  0.008407  0.000004  0.000002  3.579103e-07  0.007073
#
#         tc_pan       tc_c3h8         tcso2        tcw       tcwv  \
# 0     0.000009  6.953380e-07  2.916594e-06  25.766945  25.620820
# 1     0.000008  6.623504e-07  2.408668e-06  27.838995  27.701486
# 2     0.000009  6.841318e-07  2.561723e-06  26.076443  25.936913
# 3     0.000009  7.044878e-07  3.263775e-06  25.607194  25.458810
# 4     0.000009  7.188703e-07  3.696579e-06  24.042930  23.889293
# ...        ...           ...           ...        ...        ...
# 3122  0.000005  5.093373e-07  1.734801e-06   7.928388   7.855770
# 3123  0.000004  4.969263e-07  5.508047e-07   6.659885   6.563536
# 3124  0.000005  5.013261e-07  9.614928e-07   7.562793   7.481038
# 3125  0.000005  5.551632e-07  9.746067e-07   8.973590   8.898886
# 3126  0.000005  5.917362e-07  1.300883e-06  10.889522  10.806633
#
#          aermssdus     aermssdum     aermssdul  aermssbchphil  aermssomhphil  \
# 0     2.109251e-06  4.289945e-06  3.297524e-06   1.285140e-07       0.000003
# 1     2.641386e-06  5.453165e-06  4.363785e-06   1.200844e-07       0.000002
# 2     2.072566e-06  4.220296e-06  3.329836e-06   1.460098e-07       0.000002
# 3     2.049331e-06  4.173433e-06  3.204589e-06   1.257123e-07       0.000003
# 4     1.644247e-06  3.319324e-06  2.564080e-06   1.292652e-07       0.000003
# ...            ...           ...           ...            ...            ...
# 3122  5.407217e-07  1.250976e-06  3.762784e-06   9.304454e-08       0.000002
# 3123  2.826886e-07  6.105456e-07  9.086884e-07   9.835064e-08       0.000002
# 3124  3.919377e-07  8.618799e-07  1.628275e-06   1.029395e-07       0.000002
# 3125  5.422676e-07  1.234555e-06  3.181389e-06   9.980623e-08       0.000002
# 3126  9.318926e-07  2.207567e-06  7.676727e-06   1.083759e-07       0.000002
#
#       aermssbchphob  aermssomhphob     aermsssss  aermssssm     aermssssl  \
# 0      5.390907e-07       0.000013  2.305156e-07   0.000016  1.011381e-06
# 1      5.609629e-07       0.000013  2.891494e-07   0.000021  2.088636e-06
# 2      5.375428e-07       0.000013  2.383421e-07   0.000016  1.124706e-06
# 3      5.365352e-07       0.000013  2.220161e-07   0.000015  9.132320e-07
# 4      5.195765e-07       0.000013  1.988160e-07   0.000013  7.093172e-07
# ...             ...            ...           ...        ...           ...
# 3122   4.126463e-07       0.000008  2.043045e-07   0.000013  9.202822e-07
# 3123   4.230261e-07       0.000008  2.082735e-07   0.000013  1.042024e-06
# 3124   4.282595e-07       0.000008  2.133426e-07   0.000013  1.042253e-06
# 3125   4.717826e-07       0.000009  2.166572e-07   0.000013  9.530186e-07
# 3126   4.645051e-07       0.000010  2.143260e-07   0.000013  8.649807e-07
#
#       aermsssu     aermssso2
# 0     0.000008  1.620365e-06
# 1     0.000008  1.140217e-06
# 2     0.000008  1.212712e-06
# 3     0.000008  1.971961e-06
# 4     0.000008  2.447597e-06
# ...        ...           ...
# 3122  0.000003  1.312529e-06
# 3123  0.000003  2.643211e-07
# 3124  0.000003  6.135119e-07
# 3125  0.000003  6.094519e-07
# 3126  0.000003  8.724334e-07
#
# [3078 rows x 47 columns]

# %%
## Lets create a Train-Test set

features=full_df.drop('MeanLifeExpectency',axis=1)
target=full_df['MeanLifeExpectency'].copy()

## a validataion is not required as we can create it when training the model
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.20)

# %%
## scale the features as it will converge to the cost function faster

scaler=StandardScaler()
X_train_scaled=scaler.fit_transform(X_train) 
X_test_scaled=scaler.transform(X_test)

# %%
## build a MLP with 2 dense layer using sequential API

model=keras.models.Sequential([
## below is the first dense dense layer with 30 neurons ( or units), relu activation function
## its a good practice to specify the input shape as well, and only include in the first layer
                            keras.layers.Dense(60, activation='relu', input_shape=X_train.shape[1:]),
## lets create a second layer. Its not quite necessary as it is only a regression task
                            keras.layers.Dense(30, activation='relu'),
## create a output layer. Since, the output is only 1, create the output layer with 1 unit
                            keras.layers.Dense(1)
                               ])
# Out:
# C:\Users\Shisir\.conda\envs\Weather_Prediction\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary() ## None means that the batch size can be anything
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 60)             │         2,820 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 30)             │         1,830 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            31 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,681 (18.29 KB)
#  Trainable params: 4,681 (18.29 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
## compile the model with mse ( mean squared error) as a loss function
## Adam optimizer to find the optimal solution
## note that, sgd did not work and provided the same output.
optimizer = keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss='mean_squared_error', optimizer= optimizer)

# %%
history= model.fit(X_train_scaled, y_train, epochs=150,
                    validation_split=0.2) ## a validation set to optimize the weights and biases
# Out:
# Epoch 1/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 5590.5415 - val_loss: 3826.8850
# Epoch 2/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2759.8059 - val_loss: 790.5009
# Epoch 3/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 589.6808 - val_loss: 380.1512
# Epoch 4/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 299.5072 - val_loss: 197.9453
# Epoch 5/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 182.2335 - val_loss: 116.1030
# Epoch 6/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 109.2258 - val_loss: 79.4578
# Epoch 7/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 75.2374 - val_loss: 59.4114
# Epoch 8/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 59.6606 - val_loss: 46.7122
# Epoch 9/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.6742 - val_loss: 37.5554
# Epoch 10/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 37.0762 - val_loss: 31.2566
# Epoch 11/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 32.3204 - val_loss: 26.7268
# Epoch 12/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 24.2692 - val_loss: 23.2671
# Epoch 13/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 22.3913 - val_loss: 21.0028
# Epoch 14/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.7591 - val_loss: 19.1116
# Epoch 15/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 18.6603 - val_loss: 18.4622
# Epoch 16/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 16.8182 - val_loss: 16.0934
# Epoch 17/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 16.4923 - val_loss: 16.1703
# Epoch 18/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 14.7232 - val_loss: 15.2645
# Epoch 19/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12.7711 - val_loss: 13.9918
# Epoch 20/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12.7443 - val_loss: 13.3206
# Epoch 21/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12.3214 - val_loss: 12.6014
# Epoch 22/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11.1896 - val_loss: 12.0941
# Epoch 23/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.5334 - val_loss: 12.0138
# Epoch 24/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.0371 - val_loss: 11.3800
# Epoch 25/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.4868 - val_loss: 10.7279
# Epoch 26/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.3427 - val_loss: 10.5798
# Epoch 27/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.4542 - val_loss: 10.4894
# Epoch 28/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.4261 - val_loss: 9.7893
# Epoch 29/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.3510 - val_loss: 9.6532
# Epoch 30/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.9824 - val_loss: 9.3498
# Epoch 31/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.0543 - val_loss: 8.7975
# Epoch 32/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.7974 - val_loss: 9.1332
# Epoch 33/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.5175 - val_loss: 8.3708
# Epoch 34/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.7447 - val_loss: 8.5378
# Epoch 35/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.1590 - val_loss: 8.2005
# Epoch 36/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.4610 - val_loss: 7.9833
# Epoch 37/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.5491 - val_loss: 8.0173
# Epoch 38/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.2808 - val_loss: 7.7693
# Epoch 39/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.9713 - val_loss: 8.0096
# Epoch 40/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4123 - val_loss: 7.5210
# Epoch 41/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.2121 - val_loss: 7.2501
# Epoch 42/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.9539 - val_loss: 7.0603
# Epoch 43/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.9615 - val_loss: 7.0661
# Epoch 44/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2420 - val_loss: 6.9560
# Epoch 45/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.2628 - val_loss: 6.8963
# Epoch 46/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3644 - val_loss: 7.0274
# Epoch 47/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8882 - val_loss: 6.5831
# Epoch 48/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.2695 - val_loss: 6.5357
# Epoch 49/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1154 - val_loss: 6.4668
# Epoch 50/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3884 - val_loss: 6.4485
# Epoch 51/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8907 - val_loss: 6.4885
# Epoch 52/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7191 - val_loss: 6.3068
# Epoch 53/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3824 - val_loss: 6.2339
# Epoch 54/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5061 - val_loss: 5.8788
# Epoch 55/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0494 - val_loss: 6.2536
# Epoch 56/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2520 - val_loss: 5.7935
# Epoch 57/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0640 - val_loss: 5.8734
# Epoch 58/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1675 - val_loss: 5.7514
# Epoch 59/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0926 - val_loss: 5.4811
# Epoch 60/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2216 - val_loss: 5.5545
# Epoch 61/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7682 - val_loss: 5.7597
# Epoch 62/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9497 - val_loss: 5.7850
# Epoch 63/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8948 - val_loss: 5.2912
# Epoch 64/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9054 - val_loss: 5.4528
# Epoch 65/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7672 - val_loss: 5.4381
# Epoch 66/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7326 - val_loss: 5.3242
# Epoch 67/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7747 - val_loss: 5.0701
# Epoch 68/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8736 - val_loss: 5.3277
# Epoch 69/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0750 - val_loss: 5.3404
# Epoch 70/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7135 - val_loss: 5.1463
# Epoch 71/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8409 - val_loss: 5.0252
# Epoch 72/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8256 - val_loss: 5.0466
# Epoch 73/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4844 - val_loss: 4.8275
# Epoch 74/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3641 - val_loss: 5.2283
# Epoch 75/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4117 - val_loss: 4.8697
# Epoch 76/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1753 - val_loss: 5.2191
# Epoch 77/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4049 - val_loss: 4.8776
# Epoch 78/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4912 - val_loss: 4.7946
# Epoch 79/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1258 - val_loss: 4.9978
# Epoch 80/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9497 - val_loss: 4.5631
# Epoch 81/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0330 - val_loss: 4.7665
# Epoch 82/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2549 - val_loss: 5.0787
# Epoch 83/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3694 - val_loss: 4.4912
# Epoch 84/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7242 - val_loss: 4.7066
# Epoch 85/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2404 - val_loss: 4.5170
# Epoch 86/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1751 - val_loss: 4.3632
# Epoch 87/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8160 - val_loss: 5.3602
# Epoch 88/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9100 - val_loss: 4.4063
# Epoch 89/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8729 - val_loss: 4.3155
# Epoch 90/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0584 - val_loss: 4.5957
# Epoch 91/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0241 - val_loss: 4.4369
# Epoch 92/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8555 - val_loss: 4.0908
# Epoch 93/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0678 - val_loss: 5.0913
# Epoch 94/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0639 - val_loss: 4.6617
# Epoch 95/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8563 - val_loss: 4.1672
# Epoch 96/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8332 - val_loss: 4.4044
# Epoch 97/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7706 - val_loss: 4.3935
# Epoch 98/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8371 - val_loss: 4.7071
# Epoch 99/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8085 - val_loss: 4.3369
# Epoch 100/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6960 - val_loss: 5.2378
# Epoch 101/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7429 - val_loss: 4.3521
# Epoch 102/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9282 - val_loss: 4.5167
# Epoch 103/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5012 - val_loss: 4.1763
# Epoch 104/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7648 - val_loss: 4.2784
# Epoch 105/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4533 - val_loss: 4.2029
# Epoch 106/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3815 - val_loss: 4.0919
# Epoch 107/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6544 - val_loss: 4.6899
# Epoch 108/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5045 - val_loss: 4.0757
# Epoch 109/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5798 - val_loss: 4.8904
# Epoch 110/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6266 - val_loss: 4.1053
# Epoch 111/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6543 - val_loss: 4.1655
# Epoch 112/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4745 - val_loss: 4.2611
# Epoch 113/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2538 - val_loss: 4.4196
# Epoch 114/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4699 - val_loss: 3.9570
# Epoch 115/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7199 - val_loss: 3.7732
# Epoch 116/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2068 - val_loss: 4.0857
# Epoch 117/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3836 - val_loss: 4.4589
# Epoch 118/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3728 - val_loss: 3.9255
# Epoch 119/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6020 - val_loss: 3.6746
# Epoch 120/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2241 - val_loss: 3.9519
# Epoch 121/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3329 - val_loss: 4.1906
# Epoch 122/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2834 - val_loss: 3.6791
# Epoch 123/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3786 - val_loss: 5.0939
# Epoch 124/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8914 - val_loss: 3.9215
# Epoch 125/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3772 - val_loss: 3.7176
# Epoch 126/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2910 - val_loss: 4.2613
# Epoch 127/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3966 - val_loss: 3.7820
# Epoch 128/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2436 - val_loss: 3.7389
# Epoch 129/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4743 - val_loss: 3.6728
# Epoch 130/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3996 - val_loss: 3.6947
# Epoch 131/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3309 - val_loss: 3.8649
# Epoch 132/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0885 - val_loss: 3.7083
# Epoch 133/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3467 - val_loss: 3.5780
# Epoch 134/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1648 - val_loss: 3.7763
# Epoch 135/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1489 - val_loss: 3.6048
# Epoch 136/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2750 - val_loss: 4.1690
# Epoch 137/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2728 - val_loss: 3.9137
# Epoch 138/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3566 - val_loss: 3.6755
# Epoch 139/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2856 - val_loss: 3.7424
# Epoch 140/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4044 - val_loss: 3.7915
# Epoch 141/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6011 - val_loss: 3.6867
# Epoch 142/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6091 - val_loss: 4.0140
# Epoch 143/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4008 - val_loss: 3.6439
# Epoch 144/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9668 - val_loss: 3.6739
# Epoch 145/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3238 - val_loss: 3.9936
# Epoch 146/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5149 - val_loss: 4.7125
# Epoch 147/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3465 - val_loss: 4.1297
# Epoch 148/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3321 - val_loss: 4.2508
# Epoch 149/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3979 - val_loss: 3.9614
# Epoch 150/150
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9635 - val_loss: 3.4777

# %%
## plot the train and validation loss

pd.DataFrame(history.history).plot(figsize=(8, 5)) 
plt.grid(axis='both',linewidth=0.15)
## set the ylim as the validation loss is way high in the first epoch
plt.gca().set_ylim(0, 10) 
plt.show()

# %% [markdown]
# #### The validation loss is close to the training loss and is starting to plateau, so its good enough.

# %%
mse_train=model.evaluate(X_train_scaled, y_train)
mse_test=model.evaluate(X_test_scaled, y_test)
# Out:
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1329
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8062

# %%
train_prediction=model.predict(X_train_scaled).flatten()
test_prediction=model.predict(X_test_scaled).flatten()
# Out:
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
y_train=y_train.to_numpy()
y_test=y_test.to_numpy()

# %%
train_prediction
# Out:
# array([73.960236, 77.88983 , 76.10592 , ..., 79.44603 , 76.23552 ,
#        76.7719  ], dtype=float32)

# %%
## train rmse

mse_train=mean_squared_error(y_train, train_prediction)
rmse_train=np.sqrt(mse_train)
rmse_train=int(rmse_train*100)/100 ## display only two digits without rounding

print('The train RMSE :::', '%.2f' % rmse_train)

## test rmse

mse_test=mean_squared_error(y_test,test_prediction)
rmse_test=np.sqrt(mse_test)
rmse_test=int(rmse_test*100)/100 

print('The test RMSE :::', '%.2f' % rmse_test)
# Out:
# The train RMSE ::: 1.52
# The test RMSE ::: 1.64

# %%
## the train r square

train_r_sq=(pearsonr(y_train,train_prediction)[0])**2
corr_train=int(train_r_sq*100)/100 ## display only two digits without rounding

print('The train r_sq :::', '%.2f' % corr_train)
## The test r square

test_r_sq=(pearsonr(y_test,test_prediction)[0])**2
corr_test=int(test_r_sq*100)/100 ## display only two digits without rounding

print('The test r_sq :::', '%.2f' % corr_test)
# Out:
# The train r_sq ::: 0.59
# The test r_sq ::: 0.50

# %% [markdown]
# ### The results are again worse than Random Forest, I wont draw the scatter plot and qqplots.
