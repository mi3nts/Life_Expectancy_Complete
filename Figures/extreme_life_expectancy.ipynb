# %%
#### conda env Weather_Prediction

import pandas as pd
import matplotlib.pyplot as plt
import os
import geopandas as gpd
pd.set_option('display.precision', 15)
pd.set_option('display.max_columns', None)

# %%
## year to plot and estimate

select_year = 2019
year = str(select_year)
PATH_3 = os.path.join('..','Results','CAMS_with_LE', 'LE_'+year +'.csv') ## read the life expectancy data
le = pd.read_csv(PATH_3)
le
# Out:
#                     location_name   fips  year  MeanLifeExpectency
# 0        Autauga County (Alabama)   1001  2019  76.593265140000000
# 1        Baldwin County (Alabama)   1003  2019  78.293522339999996
# 2        Barbour County (Alabama)   1005  2019  74.814532090000000
# 3           Bibb County (Alabama)   1007  2019  73.920053800000005
# 4         Blount County (Alabama)   1009  2019  75.029185549999994
# ...                           ...    ...   ...                 ...
# 3122  Sweetwater County (Wyoming)  56037  2019  78.018891969999999
# 3123       Teton County (Wyoming)  56039  2019  85.638149490000004
# 3124       Uinta County (Wyoming)  56041  2019  77.521690719999995
# 3125    Washakie County (Wyoming)  56043  2019  78.137158389999996
# 3126      Weston County (Wyoming)  56045  2019  79.189934080000000
#
# [3127 rows x 4 columns]

# %%
## load the county shapefile


if select_year==2003 or 2004 or 2005 or 2006 or 2007 or 2008 or 2009 or 2010:
    SHAPE_PATH=os.path.join('..','Shapefiles','county_shapefiles','2010_county_shapefile',
                        'gz_2010_us_050_00_500k.shp')
    county_gdf = gpd.read_file(SHAPE_PATH)
    county_gdf = county_gdf.rename(columns={'STATE':'STATEFP','COUNTY':'COUNTYFP'}) ## rename to be consistent with other 

elif select_year == 2011:
    SHAPE_PATH=os.path.join('..','..','..','Shapefiles','county_shapefiles','2011_county_shapefile','tl_2011_us_county.shp')
    county_gdf = gpd.read_file(SHAPE_PATH)
    
elif select_year == 2012:

    SHAPE_PATH=os.path.join('..','..','..','Shapefiles','county_shapefiles','2012_county_shapefile','tl_2012_us_county.shp')
    county_gdf = gpd.read_file(SHAPE_PATH)
    
elif select_year == 2013:
    SHAPE_PATH=os.path.join('..','..','..','Shapefiles','county_shapefiles','2013_county_shapefile','cb_2013_us_county_500k.shp')
    county_gdf = gpd.read_file(SHAPE_PATH)

elif select_year == 2014:
    SHAPE_PATH=os.path.join('..','..','..','Shapefiles','county_shapefiles','2014_county_shapefile','cb_2014_us_county_500k.shp')
    county_gdf = gpd.read_file(SHAPE_PATH)

elif select_year == 2015:
    SHAPE_PATH=os.path.join('..','..','..','Shapefiles','county_shapefiles','2015_county_shapefile','cb_2015_us_county_500k.shp')
    county_gdf = gpd.read_file(SHAPE_PATH)

elif select_year == 2016:
    SHAPE_PATH=os.path.join('..','..','..','Shapefiles','county_shapefiles','2016_county_shapefile','cb_2016_us_county_500k.shp')
    county_gdf = gpd.read_file(SHAPE_PATH)

elif select_year == 2017:
    SHAPE_PATH=os.path.join('..','..','..','Shapefiles','county_shapefiles','2017_county_shapefile','cb_2017_us_county_500k.shp')
    county_gdf = gpd.read_file(SHAPE_PATH)

elif select_year == 2018:
    SHAPE_PATH=os.path.join('..','..','..','Shapefiles','county_shapefiles','2018_county_shapefile','cb_2018_us_county_500k.shp')
    county_gdf = gpd.read_file(SHAPE_PATH)

elif select_year == 2019:

    SHAPE_PATH=os.path.join('..','Shapefiles','county_shapefiles','2019_county_shapefile',
                        'cb_2019_us_county_500k.shp')
    county_gdf = gpd.read_file(SHAPE_PATH)

else:
    print('no year exist')

# %%
county_gdf
# Out:
#               GEO_ID STATEFP COUNTYFP           NAME    LSAD  \
# 0     0500000US01029      01      029       Cleburne  County
# 1     0500000US01031      01      031         Coffee  County
# 2     0500000US01037      01      037          Coosa  County
# 3     0500000US01039      01      039      Covington  County
# 4     0500000US01041      01      041       Crenshaw  County
# ...              ...     ...      ...            ...     ...
# 3216  0500000US72131      72      131  San Sebastián    Muno
# 3217  0500000US72133      72      133   Santa Isabel    Muno
# 3218  0500000US72137      72      137       Toa Baja    Muno
# 3219  0500000US72139      72      139  Trujillo Alto    Muno
# 3220  0500000US72153      72      153          Yauco    Muno
#
#                 CENSUSAREA                                           geometry
# 0      560.100000000000023  POLYGON ((-85.38872 33.91304, -85.38088 33.873...
# 1      678.971999999999980  POLYGON ((-86.03044 31.61894, -86.00408 31.619...
# 2      650.926000000000045  POLYGON ((-86.00928 33.10164, -86.00917 33.090...
# 3     1030.455999999999904  POLYGON ((-86.34851 30.99434, -86.35023 30.994...
# 4      608.840000000000032  POLYGON ((-86.14699 31.68046, -86.14711 31.663...
# ...                    ...                                                ...
# 3216    70.423000000000002  POLYGON ((-66.90748 18.25314, -66.90739 18.253...
# 3217    34.023000000000003  POLYGON ((-66.37968 17.94398, -66.38029 17.943...
# 3218    23.241000000000000  MULTIPOLYGON (((-66.13957 18.46232, -66.13956 ...
# 3219    20.763999999999999  POLYGON ((-66.02917 18.3759, -66.02828 18.3768...
# 3220    68.191999999999993  POLYGON ((-66.85229 17.955, -66.8528 17.95519,...
#
# [3221 rows x 7 columns]

# %%
county_gdf['fips']=county_gdf['STATEFP'] + county_gdf['COUNTYFP']
    ## convert the data type
county_gdf['fips']=county_gdf['fips'].astype(str).astype(int)
## convert dtype to int

county_gdf['STATEFP']=county_gdf['STATEFP'].astype(str).astype(int) 
county_gdf.dtypes

county_gdf=county_gdf.loc[:,['STATEFP','geometry','fips']]
county_gdf.dtypes
# Out:
# STATEFP        int64
# geometry    geometry
# fips           int64
# dtype: object

# %%
## load state shapefile

SHAPE_PATH = os.path.join('..','Shapefiles','state_shapefile','cb_2018_us_state_500k.shp')
state_shape = gpd.read_file(SHAPE_PATH)

print('The CRS of the SHAPE file is:', state_shape.crs)

## include only contiguous shapefile

remove_state = ['Alaska', 'District of Columbia', 'American Samoa', 'United States Virgin Islands', 'Hawaii', 'Guam', 
                  'Commonwealth of the Northern Mariana Islands', 'Puerto Rico' ]

# Remove rows where the 'NAME' column contains any value from strings
state_shape = state_shape[~state_shape['NAME'].isin(remove_state)]
state_shape
# Out:
# The CRS of the SHAPE file is: EPSG:4269
#    STATEFP   STATENS     AFFGEOID GEOID STUSPS            NAME LSAD  \
# 0       28  01779790  0400000US28    28     MS     Mississippi   00
# 1       37  01027616  0400000US37    37     NC  North Carolina   00
# 2       40  01102857  0400000US40    40     OK        Oklahoma   00
# 3       51  01779803  0400000US51    51     VA        Virginia   00
# 4       54  01779805  0400000US54    54     WV   West Virginia   00
# 5       22  01629543  0400000US22    22     LA       Louisiana   00
# 6       26  01779789  0400000US26    26     MI        Michigan   00
# 7       25  00606926  0400000US25    25     MA   Massachusetts   00
# 8       16  01779783  0400000US16    16     ID           Idaho   00
# 9       12  00294478  0400000US12    12     FL         Florida   00
# 10      31  01779792  0400000US31    31     NE        Nebraska   00
# 11      53  01779804  0400000US53    53     WA      Washington   00
# 12      35  00897535  0400000US35    35     NM      New Mexico   00
# 14      46  01785534  0400000US46    46     SD    South Dakota   00
# 15      48  01779801  0400000US48    48     TX           Texas   00
# 16      06  01779778  0400000US06    06     CA      California   00
# 17      01  01779775  0400000US01    01     AL         Alabama   00
# 18      13  01705317  0400000US13    13     GA         Georgia   00
# 19      42  01779798  0400000US42    42     PA    Pennsylvania   00
# 20      29  01779791  0400000US29    29     MO        Missouri   00
# 21      08  01779779  0400000US08    08     CO        Colorado   00
# 22      49  01455989  0400000US49    49     UT            Utah   00
# 23      47  01325873  0400000US47    47     TN       Tennessee   00
# 24      56  01779807  0400000US56    56     WY         Wyoming   00
# 25      36  01779796  0400000US36    36     NY        New York   00
# 26      20  00481813  0400000US20    20     KS          Kansas   00
# 28      32  01779793  0400000US32    32     NV          Nevada   00
# 29      17  01779784  0400000US17    17     IL        Illinois   00
# 30      50  01779802  0400000US50    50     VT         Vermont   00
# 31      30  00767982  0400000US30    30     MT         Montana   00
# 32      19  01779785  0400000US19    19     IA            Iowa   00
# 33      45  01779799  0400000US45    45     SC  South Carolina   00
# 34      33  01779794  0400000US33    33     NH   New Hampshire   00
# 35      04  01779777  0400000US04    04     AZ         Arizona   00
# 39      34  01779795  0400000US34    34     NJ      New Jersey   00
# 40      24  01714934  0400000US24    24     MD        Maryland   00
# 41      23  01779787  0400000US23    23     ME           Maine   00
# 43      10  01779781  0400000US10    10     DE        Delaware   00
# 46      44  01219835  0400000US44    44     RI    Rhode Island   00
# 47      21  01779786  0400000US21    21     KY        Kentucky   00
# 48      39  01085497  0400000US39    39     OH            Ohio   00
# 49      55  01779806  0400000US55    55     WI       Wisconsin   00
# 50      41  01155107  0400000US41    41     OR          Oregon   00
# 51      38  01779797  0400000US38    38     ND    North Dakota   00
# 52      05  00068085  0400000US05    05     AR        Arkansas   00
# 53      18  00448508  0400000US18    18     IN         Indiana   00
# 54      27  00662849  0400000US27    27     MN       Minnesota   00
# 55      09  01779780  0400000US09    09     CT     Connecticut   00
#
#            ALAND        AWATER  \
# 0   121533519481    3926919758
# 1   125923656064   13466071395
# 2   177662925723    3374587997
# 3   102257717110    8528531774
# 4    62266474513     489028543
# 5   111897594374   23753621895
# 6   146600952990  103885855702
# 7    20205125364    7129925486
# 8   214049787659    2391722557
# 9   138949136250   31361101223
# 10  198956658395    1371829134
# 11  172112588220   12559278850
# 12  314196306401     728776523
# 14  196346981786    3382720225
# 15  676653171537   19006305260
# 16  403503931312   20463871877
# 17  131174048583    4593327154
# 18  149482048342    4422936154
# 19  115884442321    3394589990
# 20  178050802184    2489425460
# 21  268422891711    1181621593
# 22  212886221680    6998824394
# 23  106802728188    2350123465
# 24  251458544898    1867670745
# 25  122049149763   19246994695
# 26  211755344060    1344141205
# 28  284329506470    2047206072
# 29  143780567633    6214824948
# 30   23874175944    1030416650
# 31  376962738765    3869208832
# 32  144661267977    1084180812
# 33   77864918488    5075218778
# 34   23189413166    1026675248
# 35  294198551143    1027337603
# 39   19047825980    3544860246
# 40   25151100280    6979966958
# 41   79887426037   11746549764
# 43    5045925646    1399985648
# 46    2677779902    1323670487
# 47  102279490672    2375337755
# 48  105828882568   10268850702
# 49  140290039723   29344951758
# 50  248606993270    6192386935
# 51  178707534813    4403267548
# 52  134768872727    2962859592
# 53   92789302676    1538002829
# 54  206228939448   18945217189
# 55   12542497068    1815617571
#
#                                              geometry
# 0   MULTIPOLYGON (((-88.50297 30.21524, -88.49176 ...
# 1   MULTIPOLYGON (((-75.72681 35.93584, -75.71827 ...
# 2   POLYGON ((-103.00256 36.52659, -103.00219 36.6...
# 3   MULTIPOLYGON (((-75.74241 37.80835, -75.74151 ...
# 4   POLYGON ((-82.6432 38.16909, -82.643 38.16956,...
# 5   MULTIPOLYGON (((-88.8677 29.86155, -88.86566 2...
# 6   MULTIPOLYGON (((-83.19159 42.03537, -83.18993 ...
# 7   MULTIPOLYGON (((-70.23405 41.28565, -70.22361 ...
# 8   POLYGON ((-117.24267 44.39655, -117.23484 44.3...
# 9   MULTIPOLYGON (((-80.17628 25.52505, -80.17395 ...
# 10  POLYGON ((-104.05342 41.17054, -104.05324 41.1...
# 11  MULTIPOLYGON (((-122.57039 48.53785, -122.5686...
# 12  POLYGON ((-109.05017 31.48, -109.04984 31.4995...
# 14  POLYGON ((-104.05788 44.9976, -104.05078 44.99...
# 15  MULTIPOLYGON (((-94.7183 29.72886, -94.71721 2...
# 16  MULTIPOLYGON (((-118.60442 33.47855, -118.5987...
# 17  MULTIPOLYGON (((-88.05338 30.50699, -88.05109 ...
# 18  MULTIPOLYGON (((-81.27939 31.30792, -81.27716 ...
# 19  POLYGON ((-80.51989 40.90666, -80.51909 40.921...
# 20  POLYGON ((-95.77355 40.5782, -95.76853 40.5833...
# 21  POLYGON ((-109.06025 38.59933, -109.05954 38.7...
# 22  POLYGON ((-114.05296 37.59278, -114.05247 37.6...
# 23  POLYGON ((-90.3103 35.0043, -90.30988 35.00975...
# 24  POLYGON ((-111.05456 45.00096, -111.04507 45.0...
# 25  MULTIPOLYGON (((-72.03683 41.24984, -72.03496 ...
# 26  POLYGON ((-102.05174 40.00308, -101.9167 40.00...
# 28  POLYGON ((-120.00574 39.22866, -120.00559 39.2...
# 29  POLYGON ((-91.51297 40.18106, -91.51107 40.188...
# 30  POLYGON ((-73.43774 44.04501, -73.43199 44.063...
# 31  POLYGON ((-116.04914 48.50205, -116.04913 48.5...
# 32  POLYGON ((-96.6397 42.73707, -96.63589 42.741,...
# 33  MULTIPOLYGON (((-79.50795 33.02008, -79.50713 ...
# 34  MULTIPOLYGON (((-70.61702 42.97718, -70.61529 ...
# 35  POLYGON ((-114.81629 32.50804, -114.81432 32.5...
# 39  POLYGON ((-75.5591 39.62906, -75.55945 39.6298...
# 40  MULTIPOLYGON (((-76.05015 37.9869, -76.04998 3...
# 41  MULTIPOLYGON (((-67.3558 44.64226, -67.35437 4...
# 43  MULTIPOLYGON (((-75.56555 39.51485, -75.56174 ...
# 46  MULTIPOLYGON (((-71.28802 41.64558, -71.28647 ...
# 47  MULTIPOLYGON (((-89.40565 36.52816, -89.39868 ...
# 48  MULTIPOLYGON (((-82.73571 41.60336, -82.73392 ...
# 49  MULTIPOLYGON (((-86.95617 45.35549, -86.95463 ...
# 50  MULTIPOLYGON (((-123.59892 46.25145, -123.5984...
# 51  POLYGON ((-104.04868 48.86378, -104.04865 48.8...
# 52  POLYGON ((-94.61783 36.49941, -94.61765 36.499...
# 53  POLYGON ((-88.09776 37.90403, -88.09448 37.905...
# 54  MULTIPOLYGON (((-89.59206 47.96668, -89.59147 ...
# 55  MULTIPOLYGON (((-72.76143 41.24233, -72.75973 ...

# %%
## convert dtype to int

state_shape['STATEFP']=state_shape['STATEFP'].astype(str).astype(int) 
state_shape=state_shape.loc[:,['STATEFP','geometry']]
state_shape.dtypes

## this step is necessary because there are two columns named geometry
state_shape_to_merge=state_shape.rename(columns={'geometry':'state_geometry'})

# %%
gpd_df_initial = pd.merge(county_gdf, state_shape_to_merge, on='STATEFP', how='left') 
gpd_df_initial
gpd_df_initial=gpd_df_initial.dropna()
gpd_df_initial
## It is VERY IMPORTANT that the left dataframe that is merged is a Geopandas Dataframe
## Not pandas dataframe. While a Geopandas dataframe can be easily plotted, a pandas  
## even if it consists Geometry column, geopandas will not recognize it and it will not be plotted
# Out:
#       STATEFP                                           geometry   fips  \
# 0           1  POLYGON ((-85.38872 33.91304, -85.38088 33.873...   1029
# 1           1  POLYGON ((-86.03044 31.61894, -86.00408 31.619...   1031
# 2           1  POLYGON ((-86.00928 33.10164, -86.00917 33.090...   1037
# 3           1  POLYGON ((-86.34851 30.99434, -86.35023 30.994...   1039
# 4           1  POLYGON ((-86.14699 31.68046, -86.14711 31.663...   1041
# ...       ...                                                ...    ...
# 3138       56  POLYGON ((-104.05298 42.85955, -104.05286 42.7...  56027
# 3139       56  POLYGON ((-104.77417 42.60996, -104.76422 42.6...  56031
# 3140       56  POLYGON ((-109.05008 41.00066, -109.17368 41.0...  56037
# 3141       56  POLYGON ((-107.12892 43.99455, -107.12797 43.9...  56043
# 3142       56  POLYGON ((-104.05518 43.76163, -104.05514 43.7...  56045
#
#                                          state_geometry
# 0     MULTIPOLYGON (((-88.05338 30.50699, -88.05109 ...
# 1     MULTIPOLYGON (((-88.05338 30.50699, -88.05109 ...
# 2     MULTIPOLYGON (((-88.05338 30.50699, -88.05109 ...
# 3     MULTIPOLYGON (((-88.05338 30.50699, -88.05109 ...
# 4     MULTIPOLYGON (((-88.05338 30.50699, -88.05109 ...
# ...                                                 ...
# 3138  POLYGON ((-111.05456 45.00096, -111.04507 45.0...
# 3139  POLYGON ((-111.05456 45.00096, -111.04507 45.0...
# 3140  POLYGON ((-111.05456 45.00096, -111.04507 45.0...
# 3141  POLYGON ((-111.05456 45.00096, -111.04507 45.0...
# 3142  POLYGON ((-111.05456 45.00096, -111.04507 45.0...
#
# [3108 rows x 4 columns]

# %%
gpd_df_initial = gpd_df_initial.drop('state_geometry', axis=1)

# %%
gpd_df = pd.merge(gpd_df_initial, le, on='fips', how='left') ## merge dataframes to plot
gpd_df= gpd_df.dropna()
gpd_df
# Out:
#       STATEFP                                           geometry   fips  \
# 0           1  POLYGON ((-85.38872 33.91304, -85.38088 33.873...   1029
# 1           1  POLYGON ((-86.03044 31.61894, -86.00408 31.619...   1031
# 2           1  POLYGON ((-86.00928 33.10164, -86.00917 33.090...   1037
# 3           1  POLYGON ((-86.34851 30.99434, -86.35023 30.994...   1039
# 4           1  POLYGON ((-86.14699 31.68046, -86.14711 31.663...   1041
# ...       ...                                                ...    ...
# 3103       56  POLYGON ((-104.05298 42.85955, -104.05286 42.7...  56027
# 3104       56  POLYGON ((-104.77417 42.60996, -104.76422 42.6...  56031
# 3105       56  POLYGON ((-109.05008 41.00066, -109.17368 41.0...  56037
# 3106       56  POLYGON ((-107.12892 43.99455, -107.12797 43.9...  56043
# 3107       56  POLYGON ((-104.05518 43.76163, -104.05514 43.7...  56045
#
#                     location_name    year  MeanLifeExpectency
# 0       Cleburne County (Alabama)  2019.0  74.755863840000004
# 1         Coffee County (Alabama)  2019.0  76.399726470000004
# 2          Coosa County (Alabama)  2019.0  75.738481449999995
# 3      Covington County (Alabama)  2019.0  74.211589509999996
# 4       Crenshaw County (Alabama)  2019.0  74.354804810000005
# ...                           ...     ...                 ...
# 3103    Niobrara County (Wyoming)  2019.0  78.060036760000003
# 3104      Platte County (Wyoming)  2019.0  78.586807780000001
# 3105  Sweetwater County (Wyoming)  2019.0  78.018891969999999
# 3106    Washakie County (Wyoming)  2019.0  78.137158389999996
# 3107      Weston County (Wyoming)  2019.0  79.189934080000000
#
# [3077 rows x 6 columns]

# %%
gpd_df_new =gpd_df

# %%
gpd_df_new = gpd_df_new.sort_values(by='MeanLifeExpectency', ascending=True)
gpd_df_new = gpd_df_new.reset_index()
gpd_df_new
# Out:
#       index  STATEFP                                           geometry  \
# 0      2377       46  POLYGON ((-102.78939 42.99998, -102.79211 42.9...
# 1      2903       51  POLYGON ((-79.86974 36.66451, -79.87476 36.665...
# 2      2380       46  POLYGON ((-100.907 42.99791, -100.95836 42.997...
# 3       348       12  POLYGON ((-82.45836 30.13645, -82.44735 30.137...
# 4      1980       38  POLYGON ((-100.75146 45.94366, -100.76207 45.9...
# ...     ...      ...                                                ...
# 3072   3098       56  POLYGON ((-111.04668 43.8083, -111.04672 43.81...
# 3073    262        8  POLYGON ((-109.04197 38.13195, -109.04184 38.1...
# 3074    244        8  POLYGON ((-107.11366 39.46692, -107.11364 39.4...
# 3075    258        8  POLYGON ((-107.20322 39.36599, -107.16937 39.3...
# 3076    263        8  POLYGON ((-106.17679 39.84904, -106.17353 39.8...
#
#        fips                  location_name    year  MeanLifeExpectency
# 0     46113  Shannon County (South Dakota)  2019.0  65.423110789999996
# 1     51690   Martinsville City (Virginia)  2019.0  67.615852669999995
# 2     46121     Todd County (South Dakota)  2019.0  67.696661919999997
# 3     12125         Union County (Florida)  2019.0  67.777652959999998
# 4     38085    Sioux County (North Dakota)  2019.0  68.402907790000000
# ...     ...                            ...     ...                 ...
# 3072  56039         Teton County (Wyoming)  2019.0  85.638149490000004
# 3073   8113   San Miguel County (Colorado)  2019.0  86.840500239999997
# 3074   8037        Eagle County (Colorado)  2019.0  89.037765870000001
# 3075   8097       Pitkin County (Colorado)  2019.0  91.953377149999994
# 3076   8117       Summit County (Colorado)  2019.0  92.253858359999995
#
# [3077 rows x 7 columns]

# %%
gpd_df_new_5th_percentile = int(0.05*len(gpd_df_new))
gpd_df_new_5th_percentile
# Out:
# 153

# %%
gpd_df_new_95th_percentile = int(0.95*len(gpd_df_new))
gpd_df_new_95th_percentile
# Out:
# 2923

# %%
gpd_df_new_5th = gpd_df_new.iloc[:gpd_df_new_5th_percentile]
gpd_df_new_5th
# Out:
#      index  STATEFP                                           geometry   fips  \
# 0     2377       46  POLYGON ((-102.78939 42.99998, -102.79211 42.9...  46113
# 1     2903       51  POLYGON ((-79.86974 36.66451, -79.87476 36.665...  51690
# 2     2380       46  POLYGON ((-100.907 42.99791, -100.95836 42.997...  46121
# 3      348       12  POLYGON ((-82.45836 30.13645, -82.44735 30.137...  12125
# 4     1980       38  POLYGON ((-100.75146 45.94366, -100.76207 45.9...  38085
# ..     ...      ...                                                ...    ...
# 148   1069       21  POLYGON ((-83.70951 38.00932, -83.71219 38.009...  21011
# 149    400       13  POLYGON ((-84.66546 31.06823, -84.73085 31.069...  13201
# 150   1516       29  POLYGON ((-90.64557 37.7203, -90.64604 37.7046...  29093
# 151   2112       40  POLYGON ((-94.47978 33.85671, -94.47995 33.851...  40089
# 152   2325       45  POLYGON ((-81.65508 34.90152, -81.65195 34.901...  45087
#
#                      location_name    year  MeanLifeExpectency
# 0    Shannon County (South Dakota)  2019.0  65.423110789999996
# 1     Martinsville City (Virginia)  2019.0  67.615852669999995
# 2       Todd County (South Dakota)  2019.0  67.696661919999997
# 3           Union County (Florida)  2019.0  67.777652959999998
# 4      Sioux County (North Dakota)  2019.0  68.402907790000000
# ..                             ...     ...                 ...
# 148         Bath County (Kentucky)  2019.0  73.114819400000002
# 149        Miller County (Georgia)  2019.0  73.123478700000007
# 150         Iron County (Missouri)  2019.0  73.132195690000003
# 151    McCurtain County (Oklahoma)  2019.0  73.135133830000001
# 152  Union County (South Carolina)  2019.0  73.139433130000000
#
# [153 rows x 7 columns]

# %%
gpd_df_new_95th = gpd_df_new.iloc[gpd_df_new_95th_percentile:]
gpd_df_new_95th
# Out:
#       index  STATEFP                                           geometry  \
# 2923   2546       48  POLYGON ((-97.69061 30.04246, -97.69138 30.041...
# 2924    237        8  POLYGON ((-106.38592 38.62672, -106.38627 38.6...
# 2925   1192       25  MULTIPOLYGON (((-71.13201 42.34777, -71.12975 ...
# 2926   1655       31  POLYGON ((-97.01976 41.91701, -97.01972 41.975...
# 2927   1986       38  POLYGON ((-100.83802 46.76049, -100.83941 46.7...
# ...     ...      ...                                                ...
# 3072   3098       56  POLYGON ((-111.04668 43.8083, -111.04672 43.81...
# 3073    262        8  POLYGON ((-109.04197 38.13195, -109.04184 38.1...
# 3074    244        8  POLYGON ((-107.11366 39.46692, -107.11364 39.4...
# 3075    258        8  POLYGON ((-107.20322 39.36599, -107.16937 39.3...
# 3076    263        8  POLYGON ((-106.17679 39.84904, -106.17353 39.8...
#
#        fips                   location_name    year  MeanLifeExpectency
# 2923  48453           Travis County (Texas)  2019.0  81.680549790000001
# 2924   8015       Chaffee County (Colorado)  2019.0  81.680562699999996
# 2925  25021  Norfolk County (Massachusetts)  2019.0  81.684043209999999
# 2926  31039        Cuming County (Nebraska)  2019.0  81.704690139999997
# 2927  38015  Burleigh County (North Dakota)  2019.0  81.705684120000001
# ...     ...                             ...     ...                 ...
# 3072  56039          Teton County (Wyoming)  2019.0  85.638149490000004
# 3073   8113    San Miguel County (Colorado)  2019.0  86.840500239999997
# 3074   8037         Eagle County (Colorado)  2019.0  89.037765870000001
# 3075   8097        Pitkin County (Colorado)  2019.0  91.953377149999994
# 3076   8117        Summit County (Colorado)  2019.0  92.253858359999995
#
# [154 rows x 7 columns]

# %%
## plot the county shape file
fig, ax = plt.subplots(1, figsize=(18, 14))
ax.axis('off') ## remove axis box from map 

from mpl_toolkits.axes_grid1 import make_axes_locatable

## axis for color bar
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="1.2%", pad=-1.5) ## colorbar axis
cax.set_ylabel("", fontsize=14)
cax.tick_params(labelsize = 12)
gpd_df_new_5th.plot(ax=ax,column='MeanLifeExpectency', legend=True,
                    cax=cax, legend_kwds={"label": "Life Expectancy Lower $\\mathrm{5^{th}}$ Percentile (in Years)", 
                                                                         }, vmin=65, vmax=75)

cax = divider.append_axes("right", size="1.2%", pad=1) ## colorbar axis
cax.set_ylabel("", fontsize=14)
cax.tick_params(labelsize = 12)
gpd_df_new_95th.plot(ax=ax,column='MeanLifeExpectency',cmap='Reds', legend=True,
                    cax=cax, legend_kwds={"label": "Life Expectancy Upper $\\mathrm{95^{th}}$ Percentile (in Years)", 
                                                                         }, vmin=80, vmax=95)
## overlay state shapefile
state_shape.plot(facecolor='none', edgecolor='black', ax=ax, linewidth=0.25)

# add a title and annotation
hfont = {'fontname':'Times New Roman'}
ax.set_title(year, **hfont, fontdict={'fontsize': '40', 'fontweight' : '1'})
#ax.set_title('True Life Expectancy in '+ year, **hfont, fontdict={'fontsize': '40', 'fontweight' : '1'})

file_name='True_'+year
PATH_2 = os.path.join("Extreme_LE_plots", file_name)
plt.savefig(PATH_2, bbox_inches='tight')
